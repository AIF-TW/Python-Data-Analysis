# %% [markdown]
# ## 資料視覺化小技巧

# %% [markdown]
# - ### 直方圖與箱型圖的比較

# %% [markdown]
# 名稱    |   優點     |   缺點
# -------|------------|----------
# 直方圖  | 呈現資料完整分佈 | 不易比較多個分布差異
# 相形圖  | 可由圖形直接了解統計量與極端值 | 呈現資訊量過少, 圖形美觀度較差

# %% [markdown]
# ---
# - ### 散佈圖的陷阱
#
# 在探討兩個數值變項的關聯時，我們很常會直接使用散佈圖來直接觀察，但散佈圖可不可能有時也會誤導我們？

# %%
# 載入套件
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# 此步驟需要 google 權限認證
# %matplotlib inline

# 讀取資料，在此同樣以鐵達尼號資料為範例
# 載入範例的資料集，這次我們使用的是鐵達尼號的資料，後續在機器學習領域上會很常見到這份資料集, 將資料集指到 google drive 底下 My Drive/Python-Data-Analysis/dataset/boston_house.csv, 如有更動此預設位子請在自行調整
df = pd.read_csv('/content/drive/My Drive/dataset/boston_house.csv')
dat.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# - #### Pseudo-continuous variable

# %%
plt.scatter(dat['CHAS'], dat['NOX'])
plt.xlabel('CHAS')
plt.ylabel('NOX')
plt.show()

# %%
# 較好的做法是使用群組的箱型圖做比較
dat.boxplot('NOX', by='CHAS')

# %%
plt.scatter(dat['TAX'], dat['RAD'])
plt.xlabel('TAX')
plt.ylabel('RAD')
plt.show()

# %%
plt.hist(dat['TAX'], bins=20)
plt.show()

# %%
# 調整透明度參數使資料分布較明顯

plt.scatter(dat['TAX'], dat['RAD'], alpha=0.1)
plt.xlabel('TAX')
plt.ylabel('RAD')
plt.show()

# %% [markdown]
# ---
#
# - ## 小結
#
# 在資料的視覺化上，其實還有很多需要注意的地方，未來大家在進行資料探索時請務必記得多方面交叉比較資訊是否一致。 另外，雖然很多圖形非常的絢麗美觀，但在資訊的呈現上其實基本的統計圖表並不輸給它們，在決定選用何種圖形前可以先思考一下目前想呈現的資訊為何，才能選擇到適合的圖形唷。
